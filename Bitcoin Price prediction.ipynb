# %% [markdown]
# # Importing tools

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
df = pd.read_csv("Bitcoin July 2010-May 2023.csv")
df
# Out:
#            Date        Open*         High          Low      Close**  \
# 0     30-Jun-23  $30,441.35   $31,256.86   $29,600.28   $30,477.25
# 1     29-Jun-23  $30,086.19   $30,796.25   $30,057.20   $30,445.35
# 2     28-Jun-23  $30,696.56   $30,703.28   $29,921.82   $30,086.25
# 3     27-Jun-23  $30,274.32   $31,006.79   $30,236.65   $30,688.16
# 4     26-Jun-23  $30,480.52   $30,636.03   $29,955.74   $30,271.13
# ...         ...          ...          ...          ...          ...
# 4731  17-Jul-10       $0.07        $0.08        $0.06        $0.07
# 4732  16-Jul-10       $0.06        $0.07        $0.06        $0.07
# 4733  15-Jul-10       $0.06        $0.07        $0.05        $0.06
# 4734  14-Jul-10       $0.06        $0.06        $0.05        $0.06
# 4735  13-Jul-10       $0.06        $0.07        $0.05        $0.06
#
#                    Volume            Market Cap
# 0     $26,387,306,197.00   $591,758,288,456.00
# 1     $13,180,860,821.00   $591,107,911,061.00
# ...

# %% [markdown]
# ### Analyzing and manipulating data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   object
#  1   Open*       4736 non-null   object
#  2   High        4736 non-null   object
#  3   Low         4736 non-null   object
#  4   Close**     4736 non-null   object
#  5   Volume      4736 non-null   object
#  6   Market Cap  4736 non-null   object
# dtypes: object(7)
# memory usage: 259.1+ KB

# %%
df
# Out:
#            Date        Open*         High          Low      Close**  \
# 0     30-Jun-23  $30,441.35   $31,256.86   $29,600.28   $30,477.25
# 1     29-Jun-23  $30,086.19   $30,796.25   $30,057.20   $30,445.35
# 2     28-Jun-23  $30,696.56   $30,703.28   $29,921.82   $30,086.25
# 3     27-Jun-23  $30,274.32   $31,006.79   $30,236.65   $30,688.16
# 4     26-Jun-23  $30,480.52   $30,636.03   $29,955.74   $30,271.13
# ...         ...          ...          ...          ...          ...
# 4731  17-Jul-10       $0.07        $0.08        $0.06        $0.07
# 4732  16-Jul-10       $0.06        $0.07        $0.06        $0.07
# 4733  15-Jul-10       $0.06        $0.07        $0.05        $0.06
# 4734  14-Jul-10       $0.06        $0.06        $0.05        $0.06
# 4735  13-Jul-10       $0.06        $0.07        $0.05        $0.06
#
#                    Volume            Market Cap
# 0     $26,387,306,197.00   $591,758,288,456.00
# 1     $13,180,860,821.00   $591,107,911,061.00
# ...

# %%
column_names = ['Open*','High', 'Low', 'Close**', 'Volume', 'Market Cap']
for i in column_names:
    df[i] = df[i].str.replace('$', '')
    df[i] = df[i].str.replace(',', '')
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_5600\2251922141.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[i] = df[i].str.replace('$', '')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   object
#  1   Open*       4736 non-null   object
#  2   High        4736 non-null   object
#  3   Low         4736 non-null   object
#  4   Close**     4736 non-null   object
#  5   Volume      4736 non-null   object
#  6   Market Cap  4736 non-null   object
# dtypes: object(7)
# memory usage: 259.1+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   object
#  1   Open*       4736 non-null   object
#  2   High        4736 non-null   object
#  3   Low         4736 non-null   object
#  4   Close**     4736 non-null   object
#  5   Volume      4736 non-null   object
#  6   Market Cap  4736 non-null   object
# dtypes: object(7)
# memory usage: 259.1+ KB

# %%
for i in column_names:
    df[i] = pd.to_numeric(df[i], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   object
#  1   Open*       4736 non-null   float64
#  2   High        4736 non-null   float64
#  3   Low         4736 non-null   float64
#  4   Close**     4736 non-null   float64
#  5   Volume      4736 non-null   float64
#  6   Market Cap  4736 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 259.1+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   datetime64[ns]
#  1   Open*       4736 non-null   float64
#  2   High        4736 non-null   float64
#  3   Low         4736 non-null   float64
#  4   Close**     4736 non-null   float64
#  5   Volume      4736 non-null   float64
#  6   Market Cap  4736 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 259.1 KB

# %%
df
# Out:
#            Date     Open*      High       Low   Close**        Volume  \
# 0    2023-06-30  30441.35  31256.86  29600.28  30477.25  2.638731e+10
# 1    2023-06-29  30086.19  30796.25  30057.20  30445.35  1.318086e+10
# 2    2023-06-28  30696.56  30703.28  29921.82  30086.25  1.457150e+10
# 3    2023-06-27  30274.32  31006.79  30236.65  30688.16  1.642883e+10
# 4    2023-06-26  30480.52  30636.03  29955.74  30271.13  1.649319e+10
# ...         ...       ...       ...       ...       ...           ...
# 4731 2010-07-17      0.07      0.08      0.06      0.07  2.000000e+01
# 4732 2010-07-16      0.06      0.07      0.06      0.07  4.970000e+02
# 4733 2010-07-15      0.06      0.07      0.05      0.06  4.460000e+02
# 4734 2010-07-14      0.06      0.06      0.05      0.06  2.620000e+02
# 4735 2010-07-13      0.06      0.07      0.05      0.06  7.500000e+01
#
#         Market Cap
# 0     5.917583e+11
# 1     5.911079e+11
# 2     5.841087e+11
# 3     5.957737e+11
# 4     5.876504e+11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   datetime64[ns]
#  1   Open*       4736 non-null   float64
#  2   High        4736 non-null   float64
#  3   Low         4736 non-null   float64
#  4   Close**     4736 non-null   float64
#  5   Volume      4736 non-null   float64
#  6   Market Cap  4736 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 259.1 KB

# %%
df = df.iloc[::-1]
df = df.reset_index(drop = True)
df
# Out:
#            Date     Open*      High       Low   Close**        Volume  \
# 0    2010-07-13      0.06      0.07      0.05      0.06  7.500000e+01
# 1    2010-07-14      0.06      0.06      0.05      0.06  2.620000e+02
# 2    2010-07-15      0.06      0.07      0.05      0.06  4.460000e+02
# 3    2010-07-16      0.06      0.07      0.06      0.07  4.970000e+02
# 4    2010-07-17      0.07      0.08      0.06      0.07  2.000000e+01
# ...         ...       ...       ...       ...       ...           ...
# 4731 2023-06-26  30480.52  30636.03  29955.74  30271.13  1.649319e+10
# 4732 2023-06-27  30274.32  31006.79  30236.65  30688.16  1.642883e+10
# 4733 2023-06-28  30696.56  30703.28  29921.82  30086.25  1.457150e+10
# 4734 2023-06-29  30086.19  30796.25  30057.20  30445.35  1.318086e+10
# 4735 2023-06-30  30441.35  31256.86  29600.28  30477.25  2.638731e+10
#
#         Market Cap
# 0     1.945110e+05
# 1     1.902600e+05
# 2     1.959820e+05
# 3     2.280470e+05
# 4     2.269050e+05
# ...

# %%
df['Year'] = df['Date'].dt.year

# %%
df
# Out:
#            Date     Open*      High       Low   Close**        Volume  \
# 0    2010-07-13      0.06      0.07      0.05      0.06  7.500000e+01
# 1    2010-07-14      0.06      0.06      0.05      0.06  2.620000e+02
# 2    2010-07-15      0.06      0.07      0.05      0.06  4.460000e+02
# 3    2010-07-16      0.06      0.07      0.06      0.07  4.970000e+02
# 4    2010-07-17      0.07      0.08      0.06      0.07  2.000000e+01
# ...         ...       ...       ...       ...       ...           ...
# 4731 2023-06-26  30480.52  30636.03  29955.74  30271.13  1.649319e+10
# 4732 2023-06-27  30274.32  31006.79  30236.65  30688.16  1.642883e+10
# 4733 2023-06-28  30696.56  30703.28  29921.82  30086.25  1.457150e+10
# 4734 2023-06-29  30086.19  30796.25  30057.20  30445.35  1.318086e+10
# 4735 2023-06-30  30441.35  31256.86  29600.28  30477.25  2.638731e+10
#
#         Market Cap  Year
# 0     1.945110e+05  2010
# 1     1.902600e+05  2010
# 2     1.959820e+05  2010
# ...

# %%
df['Day'] = df['Date'].dt.day

# %%
df
# Out:
#            Date     Open*      High       Low   Close**        Volume  \
# 0    2010-07-13      0.06      0.07      0.05      0.06  7.500000e+01
# 1    2010-07-14      0.06      0.06      0.05      0.06  2.620000e+02
# 2    2010-07-15      0.06      0.07      0.05      0.06  4.460000e+02
# 3    2010-07-16      0.06      0.07      0.06      0.07  4.970000e+02
# 4    2010-07-17      0.07      0.08      0.06      0.07  2.000000e+01
# ...         ...       ...       ...       ...       ...           ...
# 4731 2023-06-26  30480.52  30636.03  29955.74  30271.13  1.649319e+10
# 4732 2023-06-27  30274.32  31006.79  30236.65  30688.16  1.642883e+10
# 4733 2023-06-28  30696.56  30703.28  29921.82  30086.25  1.457150e+10
# 4734 2023-06-29  30086.19  30796.25  30057.20  30445.35  1.318086e+10
# 4735 2023-06-30  30441.35  31256.86  29600.28  30477.25  2.638731e+10
#
#         Market Cap  Year  Day
# 0     1.945110e+05  2010   13
# 1     1.902600e+05  2010   14
# 2     1.959820e+05  2010   15
# ...

# %%
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#            Date     Open*      High       Low   Close**        Volume  \
# 0    2010-07-13      0.06      0.07      0.05      0.06  7.500000e+01
# 1    2010-07-14      0.06      0.06      0.05      0.06  2.620000e+02
# 2    2010-07-15      0.06      0.07      0.05      0.06  4.460000e+02
# 3    2010-07-16      0.06      0.07      0.06      0.07  4.970000e+02
# 4    2010-07-17      0.07      0.08      0.06      0.07  2.000000e+01
# ...         ...       ...       ...       ...       ...           ...
# 4731 2023-06-26  30480.52  30636.03  29955.74  30271.13  1.649319e+10
# 4732 2023-06-27  30274.32  31006.79  30236.65  30688.16  1.642883e+10
# 4733 2023-06-28  30696.56  30703.28  29921.82  30086.25  1.457150e+10
# 4734 2023-06-29  30086.19  30796.25  30057.20  30445.35  1.318086e+10
# 4735 2023-06-30  30441.35  31256.86  29600.28  30477.25  2.638731e+10
#
#         Market Cap  Year  Day  Month
# 0     1.945110e+05  2010   13      7
# 1     1.902600e+05  2010   14      7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4736 non-null   datetime64[ns]
#  1   Open*       4736 non-null   float64
#  2   High        4736 non-null   float64
#  3   Low         4736 non-null   float64
#  4   Close**     4736 non-null   float64
#  5   Volume      4736 non-null   float64
#  6   Market Cap  4736 non-null   float64
#  7   Year        4736 non-null   int64
#  8   Day         4736 non-null   int64
#  9   Month       4736 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 370.1 KB

# %%
df = df.drop('Date', axis=1)

# %%
df
# Out:
#          Open*      High       Low   Close**        Volume    Market Cap  \
# 0         0.06      0.07      0.05      0.06  7.500000e+01  1.945110e+05
# 1         0.06      0.06      0.05      0.06  2.620000e+02  1.902600e+05
# 2         0.06      0.07      0.05      0.06  4.460000e+02  1.959820e+05
# 3         0.06      0.07      0.06      0.07  4.970000e+02  2.280470e+05
# 4         0.07      0.08      0.06      0.07  2.000000e+01  2.269050e+05
# ...        ...       ...       ...       ...           ...           ...
# 4731  30480.52  30636.03  29955.74  30271.13  1.649319e+10  5.876504e+11
# 4732  30274.32  31006.79  30236.65  30688.16  1.642883e+10  5.957737e+11
# 4733  30696.56  30703.28  29921.82  30086.25  1.457150e+10  5.841087e+11
# 4734  30086.19  30796.25  30057.20  30445.35  1.318086e+10  5.911079e+11
# 4735  30441.35  31256.86  29600.28  30477.25  2.638731e+10  5.917583e+11
#
#       Year  Day  Month
# 0     2010   13      7
# 1     2010   14      7
# ...

# %% [markdown]
# calculating moving average

# %%
def calculate_ma(prices, window=10):
    ma = prices.rolling(window=window).mean()
    prices['Moving Average'] = ma
    return ma

# %%
df['Moving Average'] = calculate_ma(df['Close**'])
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_5600\3933086563.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices['Moving Average'] = ma

# %%
df
# Out:
#          Open*      High       Low   Close**        Volume    Market Cap  \
# 0         0.06      0.07      0.05      0.06  7.500000e+01  1.945110e+05
# 1         0.06      0.06      0.05      0.06  2.620000e+02  1.902600e+05
# 2         0.06      0.07      0.05      0.06  4.460000e+02  1.959820e+05
# 3         0.06      0.07      0.06      0.07  4.970000e+02  2.280470e+05
# 4         0.07      0.08      0.06      0.07  2.000000e+01  2.269050e+05
# ...        ...       ...       ...       ...           ...           ...
# 4731  30480.52  30636.03  29955.74  30271.13  1.649319e+10  5.876504e+11
# 4732  30274.32  31006.79  30236.65  30688.16  1.642883e+10  5.957737e+11
# 4733  30696.56  30703.28  29921.82  30086.25  1.457150e+10  5.841087e+11
# 4734  30086.19  30796.25  30057.20  30445.35  1.318086e+10  5.911079e+11
# 4735  30441.35  31256.86  29600.28  30477.25  2.638731e+10  5.917583e+11
#
#       Year  Day  Month  Moving Average
# 0     2010   13      7             NaN
# ...

# %% [markdown]
# ### Calculating RSI

# %%
def calculate_rsi(prices, window=50):
    deltas = np.diff(prices)
    positive_deltas = deltas * (deltas > 0)
    negative_deltas = -deltas * (deltas < 0)

    avg_gain = np.mean(positive_deltas[:window])
    avg_loss = np.mean(negative_deltas[:window])
    
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    
    return rsi

# %%
calculate_rsi(df['Close**'])
# Out:
# 50.0

# %% [markdown]
# ### Calculating Bollinger Bands

# %%
def calculate_bollinger_bands(price, window=10, std_dev=2):
    """
    Calculate Bollinger Bands in a DataFrame.

    Args:
        df (DataFrame): Input DataFrame with a column containing the prices.
        window (int): Window size for the Bollinger Bands (default: 10).
        std_dev (int): Standard deviation multiplier (default: 2).

    Returns:
        DataFrame: DataFrame with Bollinger Bands columns.

    """

    # Calculate the rolling mean and standard deviation
    rolling_mean = price.rolling(window).mean()
    rolling_std = price.rolling(window).std()

    # Calculate the upper and lower Bollinger Bands
    upper_band = rolling_mean + (rolling_std * std_dev)
    lower_band = rolling_mean - (rolling_std * std_dev)

    df['Upper Band'] = upper_band
    df['Lower Band'] = lower_band
    # Create a new DataFrame to store the Bollinger Bands
    bollinger_bands = pd.DataFrame({
        'Close': price,
        'MA': rolling_mean,
        'Upper Band': upper_band,
        'Lower Band': lower_band
    })

    return bollinger_bands

# %%
calculate_bollinger_bands(df['Close**'])
# Out:
#          Close         MA    Upper Band    Lower Band
# 0         0.06        NaN           NaN           NaN
# 1         0.06        NaN           NaN           NaN
# 2         0.06        NaN           NaN           NaN
# 3         0.07        NaN           NaN           NaN
# 4         0.07        NaN           NaN           NaN
# ...        ...        ...           ...           ...
# 4731  30271.13  28996.054  32606.549672  25385.558328
# 4732  30688.16  29413.802  32698.194900  26129.409100
# 4733  30086.25  29788.806  32269.452549  27308.159451
# 4734  30445.35  30148.238  31539.356654  28757.119346
# 4735  30477.25  30363.214  30915.060921  29811.367079
#
# [4736 rows x 4 columns]

# %%
df
# Out:
#          Open*      High       Low   Close**        Volume    Market Cap  \
# 0         0.06      0.07      0.05      0.06  7.500000e+01  1.945110e+05
# 1         0.06      0.06      0.05      0.06  2.620000e+02  1.902600e+05
# 2         0.06      0.07      0.05      0.06  4.460000e+02  1.959820e+05
# 3         0.06      0.07      0.06      0.07  4.970000e+02  2.280470e+05
# 4         0.07      0.08      0.06      0.07  2.000000e+01  2.269050e+05
# ...        ...       ...       ...       ...           ...           ...
# 4731  30480.52  30636.03  29955.74  30271.13  1.649319e+10  5.876504e+11
# 4732  30274.32  31006.79  30236.65  30688.16  1.642883e+10  5.957737e+11
# 4733  30696.56  30703.28  29921.82  30086.25  1.457150e+10  5.841087e+11
# 4734  30086.19  30796.25  30057.20  30445.35  1.318086e+10  5.911079e+11
# 4735  30441.35  31256.86  29600.28  30477.25  2.638731e+10  5.917583e+11
#
#       Year  Day  Month  Moving Average    Upper Band    Lower Band
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open*           4736 non-null   float64
#  1   High            4736 non-null   float64
#  2   Low             4736 non-null   float64
#  3   Close**         4736 non-null   float64
#  4   Volume          4736 non-null   float64
#  5   Market Cap      4736 non-null   float64
#  6   Year            4736 non-null   int64
#  7   Day             4736 non-null   int64
#  8   Month           4736 non-null   int64
#  9   Moving Average  4727 non-null   float64
#  10  Upper Band      4727 non-null   float64
#  11  Lower Band      4727 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 444.1 KB

# %% [markdown]
# ### Calculating Stochastic Oscillator

# %%
def calculate_stochastic_oscillator(df, window=10):
    """
    Calculate Stochastic Oscillator in a DataFrame.

    Args:
        df (DataFrame): Input DataFrame with high, low, and close prices.
        window (int): Window size for the Stochastic Oscillator (default: 10).

    Returns:
        DataFrame: DataFrame with Stochastic Oscillator values.

    """

    # Calculate the lowest low and highest high over the window
    lowest_low = df['Low'].rolling(window).min()
    highest_high = df['High'].rolling(window).max()

    # Calculate the %K and %D values of the Stochastic Oscillator
    k_values = 100 * ((df['Close**'] - lowest_low) / (highest_high - lowest_low))
    d_values = k_values.rolling(3).mean()

    df['%K'] = k_values
    df['%D'] = d_values

# %%
calculate_stochastic_oscillator(df)

# %%
df
# Out:
#          Open*      High       Low   Close**        Volume    Market Cap  \
# 0         0.06      0.07      0.05      0.06  7.500000e+01  1.945110e+05
# 1         0.06      0.06      0.05      0.06  2.620000e+02  1.902600e+05
# 2         0.06      0.07      0.05      0.06  4.460000e+02  1.959820e+05
# 3         0.06      0.07      0.06      0.07  4.970000e+02  2.280470e+05
# 4         0.07      0.08      0.06      0.07  2.000000e+01  2.269050e+05
# ...        ...       ...       ...       ...           ...           ...
# 4731  30480.52  30636.03  29955.74  30271.13  1.649319e+10  5.876504e+11
# 4732  30274.32  31006.79  30236.65  30688.16  1.642883e+10  5.957737e+11
# 4733  30696.56  30703.28  29921.82  30086.25  1.457150e+10  5.841087e+11
# 4734  30086.19  30796.25  30057.20  30445.35  1.318086e+10  5.911079e+11
# 4735  30441.35  31256.86  29600.28  30477.25  2.638731e+10  5.917583e+11
#
#       Year  Day  Month  Moving Average    Upper Band    Lower Band         %K  \
# ...

# %% [markdown]
# ### Calculating volume weighted average price (VWAP)

# %%
df1 = pd.DataFrame()

# %%
def calculate_vwap(df):
    """
    Calculate Volume Weighted Average Price (VWAP) in a DataFrame.

    Args:
        df (DataFrame): Input DataFrame with 'Volume', 'Close', and 'Typical Price' columns.

    Returns:
        float: Volume Weighted Average Price (VWAP) value.

    """

    # Calculate the typical price
    df1['Typical Price'] = (df['High'] + df['Low'] + df['Close**']) / 3

    # Calculate the product of typical price and volume
    df1['Typical Price x Volume'] = df1['Typical Price'] * df['Volume']

    # Calculate the cumulative sum of typical price x volume
    cumulative_sum = df1['Typical Price x Volume'].cumsum()

    # Calculate the cumulative sum of volume
    cumulative_volume = df['Volume'].cumsum()

    # Calculate the VWAP
    vwap = cumulative_sum / cumulative_volume

    # Return the last VWAP value
    return vwap.iloc[-1]

# %%
calculate_vwap(df)
# Out:
# 26834.484075734537

# %% [markdown]
# ### Calculating Average True Range (ATR)

# %%
def calculate_atr(df, window=10):
    """
    Calculate Average True Range (ATR) in a DataFrame.

    Args:
        df (DataFrame): Input DataFrame with 'High', 'Low', and 'Close' prices.
        window (int): Window size for the ATR calculation (default: 10).

    Returns:
        DataFrame: DataFrame with ATR values.

    """

    # Calculate the True Range (TR)
    df1['H-L'] = df['High'] - df['Low']
    df1['H-Cp'] = abs(df['High'] - df['Close**'].shift(1))
    df1['L-Cp'] = abs(df['Low'] - df['Close**'].shift(1))
    df1['TR'] = df1[['H-L', 'H-Cp', 'L-Cp']].max(axis=1)

    # Calculate the Average True Range (ATR)
    atr = df1['TR'].rolling(window).mean()

    # Create a new DataFrame to store the ATR values
    df['ATR'] = pd.DataFrame({'ATR': atr})

# %%
calculate_atr(df)

# %%
df
# Out:
#          Open*      High       Low   Close**        Volume    Market Cap  \
# 0         0.06      0.07      0.05      0.06  7.500000e+01  1.945110e+05
# 1         0.06      0.06      0.05      0.06  2.620000e+02  1.902600e+05
# 2         0.06      0.07      0.05      0.06  4.460000e+02  1.959820e+05
# 3         0.06      0.07      0.06      0.07  4.970000e+02  2.280470e+05
# 4         0.07      0.08      0.06      0.07  2.000000e+01  2.269050e+05
# ...        ...       ...       ...       ...           ...           ...
# 4731  30480.52  30636.03  29955.74  30271.13  1.649319e+10  5.876504e+11
# 4732  30274.32  31006.79  30236.65  30688.16  1.642883e+10  5.957737e+11
# 4733  30696.56  30703.28  29921.82  30086.25  1.457150e+10  5.841087e+11
# 4734  30086.19  30796.25  30057.20  30445.35  1.318086e+10  5.911079e+11
# 4735  30441.35  31256.86  29600.28  30477.25  2.638731e+10  5.917583e+11
#
#       Year  Day  Month  Moving Average    Upper Band    Lower Band         %K  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open*           4736 non-null   float64
#  1   High            4736 non-null   float64
#  2   Low             4736 non-null   float64
#  3   Close**         4736 non-null   float64
#  4   Volume          4736 non-null   float64
#  5   Market Cap      4736 non-null   float64
#  6   Year            4736 non-null   int64
#  7   Day             4736 non-null   int64
#  8   Month           4736 non-null   int64
#  9   Moving Average  4727 non-null   float64
#  10  Upper Band      4727 non-null   float64
#  11  Lower Band      4727 non-null   float64
#  12  %K              4727 non-null   float64
#  13  %D              4725 non-null   float64
#  14  ATR             4727 non-null   float64
# dtypes: float64(12), int64(3)
# memory usage: 555.1 KB

# %%
df.to_csv('Bitcoin July 2010-May 2023 With Indicators.csv', index=False)

# %% [markdown]
# ## Cleaning Data and Observing Data

# %%
import seaborn as sns
columns = ['Open*', 'High', 'Low', 'Close**', 'Volume', 'Market Cap', 'Year', 'Day', 'Month', 'Moving Average', 'Upper Band', 'Lower Band', '%K', '%D', 'ATR']
corr_matrix = df[columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
# Specify the columns to exclude from the logarithm transformation
exclude_columns = ['Month', 'Day', 'Year']

# Create a copy of the DataFrame
df_log = df.copy()

# Apply logarithm to the numerical columns excluding the specified columns
numerical_columns = df.columns.difference(exclude_columns)
df_log[numerical_columns] = np.log(df[numerical_columns])

# Display the transformed DataFrame
print(df_log)
# Out:
#           Open*       High        Low    Close**     Volume  Market Cap  Year  \
# 0     -2.813411  -2.659260  -2.995732  -2.813411   4.317488   12.178244  2010
# 1     -2.813411  -2.813411  -2.995732  -2.813411   5.568345   12.156147  2010
# 2     -2.813411  -2.659260  -2.995732  -2.813411   6.100319   12.185778  2010
# 3     -2.813411  -2.659260  -2.813411  -2.659260   6.208590   12.337307  2010
# 4     -2.659260  -2.525729  -2.813411  -2.659260   2.995732   12.332287  2010
# ...         ...        ...        ...        ...        ...         ...   ...
# 4731  10.324843  10.329932  10.307476  10.317950  23.526213   27.099398  2023
# 4732  10.318055  10.341961  10.316810  10.331632  23.522303   27.113127  2023
# 4733  10.331906  10.332125  10.306343  10.311824  23.402333   27.093353  2023
# 4734  10.311822  10.335148  10.310858  10.323689  23.302032   27.105264  2023
# 4735  10.323557  10.349994  10.295539  10.324736  23.996149   27.106364  2023
#
# ...

# %%
# df_log = np.log(df)

# %%
df_log
# Out:
#           Open*       High        Low    Close**     Volume  Market Cap  Year  \
# 0     -2.813411  -2.659260  -2.995732  -2.813411   4.317488   12.178244  2010
# 1     -2.813411  -2.813411  -2.995732  -2.813411   5.568345   12.156147  2010
# 2     -2.813411  -2.659260  -2.995732  -2.813411   6.100319   12.185778  2010
# 3     -2.813411  -2.659260  -2.813411  -2.659260   6.208590   12.337307  2010
# 4     -2.659260  -2.525729  -2.813411  -2.659260   2.995732   12.332287  2010
# ...         ...        ...        ...        ...        ...         ...   ...
# 4731  10.324843  10.329932  10.307476  10.317950  23.526213   27.099398  2023
# 4732  10.318055  10.341961  10.316810  10.331632  23.522303   27.113127  2023
# 4733  10.331906  10.332125  10.306343  10.311824  23.402333   27.093353  2023
# 4734  10.311822  10.335148  10.310858  10.323689  23.302032   27.105264  2023
# 4735  10.323557  10.349994  10.295539  10.324736  23.996149   27.106364  2023
#
# ...

# %%
plt.boxplot(df_log['Open*']);

# %%
plt.boxplot(df_log['Close**']);

# %%
q1 = np.quantile(df_log["Open*"], 0.25)

q3 = np.quantile(df_log["Open*"], 0.75)

iqr = q3-q1


upper_bound = q3 + (1.2 * iqr)
lower_bound = q1 - (1.2 * iqr)


outliers = (df_log["Open*"] < lower_bound) | (df_log["Open*"] > upper_bound)
df_log = df_log[~outliers]

# %%
plt.boxplot(df_log['Close**']);

# %%
plt.boxplot(df_log['Open*']);

# %%
plt.boxplot(df_log['Volume']);

# %%
plt.boxplot(df_log['ATR']);

# %% [markdown]
# ## Training ML model

# %%
df_log.replace([np.inf, -np.inf], np.nan, inplace=True)

df_log.dropna(axis=0, how='any', inplace=True)
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_5600\365187265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_log.replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\samee\AppData\Local\Temp\ipykernel_5600\365187265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_log.dropna(axis=0, how='any', inplace=True)

# %%
from sklearn.model_selection import train_test_split

X = df_log.drop('Close**', axis = 1)
y = df_log['Close**']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3396, 14), (850, 14), (3396,), (850,))

# %%
X_train
# Out:
#           Open*       High        Low     Volume  Market Cap  Year  Day  \
# 2831   8.974756   9.009931   8.956600  22.772823   25.621426  2018   13
# 1827   5.676857   5.690866   5.658227  17.173355   22.142697  2015   14
# 998    4.939569   4.982853   4.744149   9.818474   21.170449  2013    6
# 1518   6.177550   6.194058   6.150155  17.224610   22.561533  2014    8
# 1596   5.931953   5.978126   5.926339  17.051920   22.349048  2014   25
# ...         ...        ...        ...        ...         ...   ...  ...
# 2351   6.672906   6.676592   6.672438  18.131483   23.266842  2016   19
# 4211  10.504289  10.510227  10.444335  24.404979   27.220605  2022   22
# 2051   6.082812   6.086456   6.035051  18.261039   22.581723  2016   23
# 717    1.887070   2.113843   1.845300  10.174468   17.945528  2012   29
# 4558   9.721978   9.738884   9.721232  23.636798   26.506039  2023    4
#
#       Month  Moving Average  Upper Band  Lower Band        %K        %D  \
# ...

# %%
df_log
# Out:
#           Open*       High        Low    Close**     Volume  Market Cap  Year  \
# 208   -0.083382   0.029559  -0.162519  -0.094311   9.079890   15.395478  2011
# 209   -0.094311  -0.072571  -0.328504  -0.094311   7.726213   15.390851  2011
# 210   -0.105361  -0.051293  -0.274437  -0.083382   8.855378   15.404654  2011
# 211   -0.083382   0.067659  -0.198451   0.000000  10.813821   15.496989  2011
# 212    0.000000   0.029559  -0.198451  -0.020203  10.187463   15.475672  2011
# ...         ...        ...        ...        ...        ...         ...   ...
# 4731  10.324843  10.329932  10.307476  10.317950  23.526213   27.099398  2023
# 4732  10.318055  10.341961  10.316810  10.331632  23.522303   27.113127  2023
# 4733  10.331906  10.332125  10.306343  10.311824  23.402333   27.093353  2023
# 4734  10.311822  10.335148  10.310858  10.323689  23.302032   27.105264  2023
# 4735  10.323557  10.349994  10.295539  10.324736  23.996149   27.106364  2023
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import cross_val_score


rfr = RandomForestRegressor()
# scores = cross_val_score(rfr, X, y, cv=5)

# scores

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_preds = rfr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("MSE", mean_squared_error(y_test, y_preds))
print("R2 Score", r2_score(y_test, y_preds))
# Out:
# MSE 0.0005272802141758329
# R2 Score 0.9999375682297603

# %%
def plot_features(columns, importances, n=20):
    df = (pd.DataFrame({"features": columns,
                       "feature_importances": importances})
         .sort_values("feature_importances", ascending=False)
         .reset_index(drop=True))
    
    # Plot the dataframe
    fig, ax = plt.subplots()
    ax.barh(df["features"][:n], df["feature_importances"][:20])
    ax.set_ylabel("Features")
    ax.set_xlabel("Feature Importance")
    ax.invert_yaxis()

# %%
X_train.columns
# Out:
# Index(['Open*', 'High', 'Low', 'Volume', 'Market Cap', 'Year', 'Day', 'Month',
#        'Moving Average', 'Upper Band', 'Lower Band', '%K', '%D', 'ATR'],
#       dtype='object')

# %%
rfr.feature_importances_
# Out:
# array([2.84483845e-02, 9.66469338e-02, 1.74878551e-01, 1.96197552e-05,
#        6.17139232e-01, 2.75289563e-05, 3.71292583e-06, 9.15331250e-06,
#        3.40948154e-02, 4.84626126e-02, 2.84638369e-05, 6.25381144e-06,
#        3.77952819e-06, 2.30958038e-04])

# %%
plot_features(X_train.columns, rfr.feature_importances_)

# %% [markdown]
# # Testing Model

# %%
check_df = pd.read_csv('check.csv')
check_df
# Out:
#          Date      Open*       High        Low    Close**       Volume  \
# 0    8-Jul-23  30,346.92  30,374.44  30,080.16  30,292.54   7509378699
# 1    7-Jul-23  29,908.00  30,434.64  29,777.28  30,342.26  13384770155
# 2    6-Jul-23  30,507.15  31,460.05  29,892.23  29,909.34  21129219509
# 3    5-Jul-23  30,778.73  30,877.33  30,225.61  30,514.17  12481622280
# 4    4-Jul-23  31,156.86  31,325.20  30,659.36  30,777.58  12810828427
# 5    3-Jul-23  30,624.52  31,375.61  30,586.51  31,156.44  15271884873
# 6    2-Jul-23  30,587.27  30,766.14  30,264.02  30,620.77  10533418042
# 7    1-Jul-23  30,471.85  30,641.29  30,328.86  30,590.08   9086606733
# 8   30-Jun-23  30,441.35  31,256.86  29,600.28  30,477.25  26387306197
# 9   29-Jun-23  30,086.19  30,796.25  30,057.20  30,445.35  13180860821
# 10  28-Jun-23  30,696.56  30,703.28  29,921.82  30,086.25  14571500779
#
#       Market Cap
# 0   588404379630
# 1   589336655274
# 2   580894851051
# 3   592615228831
# 4   597702171826
# ...

# %%
check_df = check_df[::-1].reset_index()

# %%
check_df = check_df.drop('index', axis=1)
check_df
# Out:
#          Date      Open*       High        Low    Close**       Volume  \
# 0   28-Jun-23  30,696.56  30,703.28  29,921.82  30,086.25  14571500779
# 1   29-Jun-23  30,086.19  30,796.25  30,057.20  30,445.35  13180860821
# 2   30-Jun-23  30,441.35  31,256.86  29,600.28  30,477.25  26387306197
# 3    1-Jul-23  30,471.85  30,641.29  30,328.86  30,590.08   9086606733
# 4    2-Jul-23  30,587.27  30,766.14  30,264.02  30,620.77  10533418042
# 5    3-Jul-23  30,624.52  31,375.61  30,586.51  31,156.44  15271884873
# 6    4-Jul-23  31,156.86  31,325.20  30,659.36  30,777.58  12810828427
# 7    5-Jul-23  30,778.73  30,877.33  30,225.61  30,514.17  12481622280
# 8    6-Jul-23  30,507.15  31,460.05  29,892.23  29,909.34  21129219509
# 9    7-Jul-23  29,908.00  30,434.64  29,777.28  30,342.26  13384770155
# 10   8-Jul-23  30,346.92  30,374.44  30,080.16  30,292.54   7509378699
#
#       Market Cap
# 0   584108674471
# 1   591107911061
# 2   591758288456
# 3   593974448099
# 4   594601955893
# ...

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        11 non-null     object
#  1   Open*       11 non-null     object
#  2   High        11 non-null     object
#  3   Low         11 non-null     object
#  4   Close**     11 non-null     object
#  5   Volume      11 non-null     int64
#  6   Market Cap  11 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 744.0+ bytes

# %%
check_df['Date'] = pd.to_datetime(check_df['Date'])

# %%
check_df['Year'] = check_df['Date'].dt.year
check_df['Day'] = check_df['Date'].dt.day
check_df['Month'] = check_df['Date'].dt.month

# %%
check_df
# Out:
#          Date      Open*       High        Low    Close**       Volume  \
# 0  2023-06-28  30,696.56  30,703.28  29,921.82  30,086.25  14571500779
# 1  2023-06-29  30,086.19  30,796.25  30,057.20  30,445.35  13180860821
# 2  2023-06-30  30,441.35  31,256.86  29,600.28  30,477.25  26387306197
# 3  2023-07-01  30,471.85  30,641.29  30,328.86  30,590.08   9086606733
# 4  2023-07-02  30,587.27  30,766.14  30,264.02  30,620.77  10533418042
# 5  2023-07-03  30,624.52  31,375.61  30,586.51  31,156.44  15271884873
# 6  2023-07-04  31,156.86  31,325.20  30,659.36  30,777.58  12810828427
# 7  2023-07-05  30,778.73  30,877.33  30,225.61  30,514.17  12481622280
# 8  2023-07-06  30,507.15  31,460.05  29,892.23  29,909.34  21129219509
# 9  2023-07-07  29,908.00  30,434.64  29,777.28  30,342.26  13384770155
# 10 2023-07-08  30,346.92  30,374.44  30,080.16  30,292.54   7509378699
#
#       Market Cap  Year  Day  Month
# 0   584108674471  2023   28      6
# 1   591107911061  2023   29      6
# ...

# %%
column_names = ['Open*','High', 'Low', 'Close**']
for i in column_names:
#     df[i] = df[i].str.replace('$', '')
    check_df[i] = check_df[i].str.replace(',', '')

# %%
check_df = check_df.drop('Date', axis=1)

# %%
X_train
# Out:
#           Open*       High        Low     Volume  Market Cap  Year  Day  \
# 2831   8.974756   9.009931   8.956600  22.772823   25.621426  2018   13
# 1827   5.676857   5.690866   5.658227  17.173355   22.142697  2015   14
# 998    4.939569   4.982853   4.744149   9.818474   21.170449  2013    6
# 1518   6.177550   6.194058   6.150155  17.224610   22.561533  2014    8
# 1596   5.931953   5.978126   5.926339  17.051920   22.349048  2014   25
# ...         ...        ...        ...        ...         ...   ...  ...
# 2351   6.672906   6.676592   6.672438  18.131483   23.266842  2016   19
# 4211  10.504289  10.510227  10.444335  24.404979   27.220605  2022   22
# 2051   6.082812   6.086456   6.035051  18.261039   22.581723  2016   23
# 717    1.887070   2.113843   1.845300  10.174468   17.945528  2012   29
# 4558   9.721978   9.738884   9.721232  23.636798   26.506039  2023    4
#
#       Month  Moving Average  Upper Band  Lower Band        %K        %D  \
# ...

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open*       11 non-null     object
#  1   High        11 non-null     object
#  2   Low         11 non-null     object
#  3   Close**     11 non-null     object
#  4   Volume      11 non-null     int64
#  5   Market Cap  11 non-null     int64
#  6   Year        11 non-null     int64
#  7   Day         11 non-null     int64
#  8   Month       11 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 920.0+ bytes

# %%
# Calculate the rolling mean and standard deviation
rolling_mean = check_df['Close**'].rolling(10).mean()
rolling_std = check_df['Close**'].rolling(10).std()

# Calculate the upper and lower Bollinger Bands
upper_band = rolling_mean + (rolling_std * 2)
lower_band = rolling_mean - (rolling_std * 2)

check_df['Moving Average'] = rolling_mean
check_df['Upper Band'] = upper_band
check_df['Lower Band'] = lower_band

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open*           11 non-null     object
#  1   High            11 non-null     object
#  2   Low             11 non-null     object
#  3   Close**         11 non-null     object
#  4   Volume          11 non-null     int64
#  5   Market Cap      11 non-null     int64
#  6   Year            11 non-null     int64
#  7   Day             11 non-null     int64
#  8   Month           11 non-null     int64
#  9   Moving Average  2 non-null      float64
#  10  Upper Band      2 non-null      float64
#  11  Lower Band      2 non-null      float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 1.2+ KB

# %%
check_df['Open*'] = pd.to_numeric(check_df['Open*'])
check_df['High'] = pd.to_numeric(check_df['High'])
check_df['Low'] = pd.to_numeric(check_df['Low'])
check_df['Close**'] = pd.to_numeric(check_df['Close**'])

# %%
# Calculate the lowest low and highest high over the window
lowest_low = check_df['Low'].rolling(10).min()
highest_high = check_df['High'].rolling(10).max()

# Calculate the %K and %D values of the Stochastic Oscillator
k_values = 100 * ((check_df['Close**'] - lowest_low) / (highest_high - lowest_low))
d_values = k_values.rolling(2).mean()

check_df['%K'] = k_values
check_df['%D'] = d_values
check_df
# Out:
#        Open*      High       Low   Close**       Volume    Market Cap  Year  \
# 0   30696.56  30703.28  29921.82  30086.25  14571500779  584108674471  2023
# 1   30086.19  30796.25  30057.20  30445.35  13180860821  591107911061  2023
# 2   30441.35  31256.86  29600.28  30477.25  26387306197  591758288456  2023
# 3   30471.85  30641.29  30328.86  30590.08   9086606733  593974448099  2023
# 4   30587.27  30766.14  30264.02  30620.77  10533418042  594601955893  2023
# 5   30624.52  31375.61  30586.51  31156.44  15271884873  605031166919  2023
# 6   31156.86  31325.20  30659.36  30777.58  12810828427  597702171826  2023
# 7   30778.73  30877.33  30225.61  30514.17  12481622280  592615228831  2023
# 8   30507.15  31460.05  29892.23  29909.34  21129219509  580894851051  2023
# 9   29908.00  30434.64  29777.28  30342.26  13384770155  589336655274  2023
# 10  30346.92  30374.44  30080.16  30292.54   7509378699  588404379630  2023
#
# ...

# %%
calculate_atr(check_df)

# %%
check_train_df = check_df.drop('Close**', axis = 1)

# %%
# Specify the columns to exclude from the logarithm transformation
exclude_columns = ['Month', 'Day', 'Year']

# Create a copy of the DataFrame
check_df_log = check_train_df.copy()

# Apply logarithm to the numerical columns excluding the specified columns
numerical_columns = check_train_df.columns.difference(exclude_columns)
check_df_log[numerical_columns] = np.log(check_train_df[numerical_columns])

# Display the transformed DataFrame
check_df_log
# Out:
#         Open*       High        Low     Volume  Market Cap  Year  Day  Month  \
# 0   10.331906  10.332125  10.306343  23.402333   27.093353  2023   28      6
# 1   10.311822  10.335148  10.310858  23.302032   27.105264  2023   29      6
# 2   10.323557  10.349994  10.295539  23.996149   27.106364  2023   30      6
# 3   10.324559  10.330104  10.319855  22.930067   27.110102  2023    1      7
# 4   10.328339  10.334170  10.317715  23.077819   27.111158  2023    2      7
# 5   10.329556  10.353786  10.328314  23.449279   27.128546  2023    3      7
# 6   10.346790  10.352178  10.330693  23.273557   27.116358  2023    4      7
# 7   10.334579  10.337778  10.316445  23.247523   27.107811  2023    5      7
# 8   10.325716  10.356474  10.305354  23.773923   27.087836  2023    6      7
# 9   10.305881  10.323337  10.301501  23.317383   27.102263  2023    7      7
# 10  10.320450  10.321357  10.311621  22.739419   27.100680  2023    8      7
#
# ...

# %%
print(check_train_df.columns)

print(X_train.columns)
# Out:
# Index(['Open*', 'High', 'Low', 'Volume', 'Market Cap', 'Year', 'Day', 'Month',
#        'Moving Average', 'Upper Band', 'Lower Band', '%K', '%D', 'ATR'],
#       dtype='object')
# Index(['Open*', 'High', 'Low', 'Volume', 'Market Cap', 'Year', 'Day', 'Month',
#        'Moving Average', 'Upper Band', 'Lower Band', '%K', '%D', 'ATR'],
#       dtype='object')

# %%
check_train_df
# Out:
#        Open*      High       Low       Volume    Market Cap  Year  Day  Month  \
# 0   30696.56  30703.28  29921.82  14571500779  584108674471  2023   28      6
# 1   30086.19  30796.25  30057.20  13180860821  591107911061  2023   29      6
# 2   30441.35  31256.86  29600.28  26387306197  591758288456  2023   30      6
# 3   30471.85  30641.29  30328.86   9086606733  593974448099  2023    1      7
# 4   30587.27  30766.14  30264.02  10533418042  594601955893  2023    2      7
# 5   30624.52  31375.61  30586.51  15271884873  605031166919  2023    3      7
# 6   31156.86  31325.20  30659.36  12810828427  597702171826  2023    4      7
# 7   30778.73  30877.33  30225.61  12481622280  592615228831  2023    5      7
# 8   30507.15  31460.05  29892.23  21129219509  580894851051  2023    6      7
# 9   29908.00  30434.64  29777.28  13384770155  589336655274  2023    7      7
# 10  30346.92  30374.44  30080.16   7509378699  588404379630  2023    8      7
#
# ...

# %%
check_df_log
# Out:
#         Open*       High        Low     Volume  Market Cap  Year  Day  Month  \
# 0   10.331906  10.332125  10.306343  23.402333   27.093353  2023   28      6
# 1   10.311822  10.335148  10.310858  23.302032   27.105264  2023   29      6
# 2   10.323557  10.349994  10.295539  23.996149   27.106364  2023   30      6
# 3   10.324559  10.330104  10.319855  22.930067   27.110102  2023    1      7
# 4   10.328339  10.334170  10.317715  23.077819   27.111158  2023    2      7
# 5   10.329556  10.353786  10.328314  23.449279   27.128546  2023    3      7
# 6   10.346790  10.352178  10.330693  23.273557   27.116358  2023    4      7
# 7   10.334579  10.337778  10.316445  23.247523   27.107811  2023    5      7
# 8   10.325716  10.356474  10.305354  23.773923   27.087836  2023    6      7
# 9   10.305881  10.323337  10.301501  23.317383   27.102263  2023    7      7
# 10  10.320450  10.321357  10.311621  22.739419   27.100680  2023    8      7
#
# ...

# %%
# Assuming you have an array of features for prediction
prediction_input = [[10.320450, 10.321357, 10.311621, 22.739419, 27.100680, 2023, 8, 7, 10.325894, 10.346962, 10.304373, 3.616924, 3.652205, 6.663937]]

# Predict using the Random Forest Regressor
predictions = rfr.predict(prediction_input)
# Out:
# D:\Miniconda\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
predictions
# Out:
# array([10.32082126])

# %%
original_value = np.exp(predictions)

# %%
original_value
# Out:
# array([30358.17923811])

# %% [markdown]
# # Training Model on MLP

# %%
df_log
# Out:
#           Open*       High        Low    Close**     Volume  Market Cap  Year  \
# 208   -0.083382   0.029559  -0.162519  -0.094311   9.079890   15.395478  2011
# 209   -0.094311  -0.072571  -0.328504  -0.094311   7.726213   15.390851  2011
# 210   -0.105361  -0.051293  -0.274437  -0.083382   8.855378   15.404654  2011
# 211   -0.083382   0.067659  -0.198451   0.000000  10.813821   15.496989  2011
# 212    0.000000   0.029559  -0.198451  -0.020203  10.187463   15.475672  2011
# ...         ...        ...        ...        ...        ...         ...   ...
# 4731  10.324843  10.329932  10.307476  10.317950  23.526213   27.099398  2023
# 4732  10.318055  10.341961  10.316810  10.331632  23.522303   27.113127  2023
# 4733  10.331906  10.332125  10.306343  10.311824  23.402333   27.093353  2023
# 4734  10.311822  10.335148  10.310858  10.323689  23.302032   27.105264  2023
# 4735  10.323557  10.349994  10.295539  10.324736  23.996149   27.106364  2023
#
# ...

# %%
from sklearn.neural_network import MLPRegressor

X = df_log[['Open*','High', 'Low', 'Volume', 'Market Cap', 'Year', 'Day', 'Month', 'Moving Average', 'Upper Band', 'Lower Band', '%K', '%D', 'ATR']]  # Select the input features
y = df_log['Close**']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

mlp = MLPRegressor(hidden_layer_sizes=(100, 51), activation='relu', solver='adam', random_state=42)

mlp.fit(X_train, y_train)

y_pred = mlp.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Out:
# RMSE: 0.07250020028640163

# %%
def recover_original_value(model):
    predictions = model.predict(prediction_input)
    original_value = np.exp(predictions)
    return original_value

# %%
recover_original_value(mlp)
# Out:
# D:\Miniconda\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# array([28609.1634404])
